# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalana-Lakshan/Langchain-Learning/blob/main/RAG_application_with_LangChain_and_HuggingFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch

# %%
# !pip install transformers

# %%
# !pip install numpy

# %%
# !pip install langchain

# %%
# !pip install langchain_community

# %%
# !pip install langchain_chroma

# %%
# !pip install sentence_transformers

# %% [markdown]
# #Initialize the Language Model

# %%
from langchain_community.llms import HuggingFaceHub
from google.colab import userdata

#initialize the hugging face llm
llm = HuggingFaceHub(
    repo_id="mistralai/Mistral-7B-v0.1",
    model_kwargs = {"temperature":0.1,"max_length":500},
    huggingfacehub_api_token = userdata.get('HuggingFace_API')
)
# Out:
# /tmp/ipython-input-3296206100.py:5: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEndpoint``.
#   llm = HuggingFaceHub(

# %% [markdown]
# #Initialize the Embedding Model

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2"
)

# %% [markdown]
# #Initialize Output Parser

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %% [markdown]
# #Load Pdf

# %%
# !pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-6.5.0-py3-none-any.whl.metadata (7.1 kB)
# Downloading pypdf-6.5.0-py3-none-any.whl (329 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.6/329.6 kB 16.1 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-6.5.0

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf")

docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='/g67A  Project Proposal ‒ Govi Isuru\nT eam Name\nTerraBytes\nT eam Leader\nH.M.Kalana Lakshan\nContact Email\nklacc2022@gmail.com\nContact Phone\n0703407328'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Project Overview\nAgriculture remains one of the most critical sectors in Sri Lanka, contributing significantly to food security, employment, \nand the national economy. However, farmers face increasing challenges due to crop diseases, climate uncertainty, \nmarket instability, and limited access to timely information. At the same time, government agricultural officers lack real-\ntime, field-level insights to effectively monitor and manage agricultural risks.\nGovi Isuru is a comprehensive, bilingual (Sinhala & English), web-based smart agriculture platform designed to bridge \nthe gap between farmers, buyers, and government officers.\nAI-powered Disease \nDetection\nIntelligent identification of crop \ndiseases to enable timely \nintervention.\nYield Forecasting\nPredictive analytics for \nestimating crop yields, aiding in \nplanning and resource allocation.\nMarket Intelligence\nUp-to-date information on \nmarket prices and trends for \nbetter selling decisions.\nCommunity Disease Alerts\nReal-time notifications about disease outbreaks in \nlocal farming communities.\nGovernment Dashboards\nCentralized platforms for officers to monitor \nagricultural risks and manage resources effectively.\nThe platform currently focuses on paddy, tea, and chili cultivation, with scalability to expand to other crops in the future.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='/g16  Problem Statement\nFarmer-related Challenges\nFarmers in Sri Lanka face numerous practical \ndifficulties in their day-to-day agricultural activities, \nincluding:\nInability to accurately identify crop diseases at \nearly stages\nLack of knowledge about expected yield and \nprofitability\nPoor access to real-time market prices and \ntrends\nDependence on middlemen, resulting in low \nselling prices\nLimited access to accurate weather forecasts\nNo visibility of disease outbreaks in nearby fields\nDifficulty deciding which crops to cultivate for \nmaximum yield\nLimited access to agriculture-related news and \ninnovations\nLanguage barriers due to low English proficiency\nGovernment-related Challenges\nGovernment agricultural officers also face significant \noperational challenges:\nLack of real-time data on diseases spreading \nwithin their assigned areas\nReliance on delayed, manual reporting \nmechanisms\nDifficulty monitoring regional and national \nagricultural trends\nInefficient distribution of government resources \nsuch as manure and disaster relief funds\nAbsence of a centralized digital system for data-\ndriven decision-making'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='/g18  Proposed Solution\nGovi Isuru addresses these challenges through a role-based web application with dedicated dashboards for \nfarmers, government officers, and buyers.\nFarmers\nReceive AI-powered diagnostics, \nforecasts, and market access.\nGovernment Officers\nGain district-level monitoring tools, \nanalytics, and verification \nworkflows.\nBuyers\nGain direct access to trusted \nfarmer listings and market trends.\nThe platform transforms individual farmer inputs into community-level intelligence, enabling early disease detection, \ncoordinated responses, and informed policy decisions.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='/g1A  Key Features\n/g386  Farmer Dashboard\nAI Doctor\nFarmers upload images of crops.\nAI model analyzes the image using CNN-based \ndeep learning.\nDetects diseases or confirms healthy crops for \npaddy, tea, and chili.\nReturns disease name, confidence score, Grad-\nCAM heatmap, and treatment guidance.\nYield Forecast\nPredicts expected yield using 10 years of \nhistorical Sri Lankan agricultural data.\nInputs include district, season, year, and \ncultivation details.\nDisplays district-wise yield rankings.\nMarket Trends\nPrice analytics showing historical fluctuations.\nDistrict-wise price comparison visualizations.\nMarketplace\nFarmers list harvest details (crop, quantity, price, \nlocation, contact).\nBuyers connect instantly via phone or WhatsApp.\nRating and review system builds trust and \nreputation.\nW eather Advisory\nReal-time weather conditions and 5-day forecast.\nCrop-specific advice to mitigate weather risks.\nDisease Alerts\nShows disease outbreaks locally and nationwide.\nHeatmaps, trends, and severity indicators.\nPersonalized alerts for nearby disease spread.\nAgri News\nCategorized agriculture-related news:\nFarming\nMarkets & prices\nWeather & climate\nGovernment & policy\nTechnology & innovation\nCrop Suitability\nPredicts suitable crops based on soil, climate, and \nland conditions using ML.\nCrop Assistant Chatbot\nRule-based + AI-assisted chatbot.\nSupports voice input and image-based queries.\nBilingual responses (Sinhala & English).'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 5, 'page_label': '6'}, page_content='/g1AD  Government Officer Dashboard\n\x00\nArea Dashboard\nOverview of diseases, alerts, \nand risk levels in assigned \ndistrict.\nHeatmaps and outbreak \ntrends.\nAnalytics for manure \ndistribution and disaster \nresponse planning.\n\x00\nDisease Alerts \nManagement\nArea-wide disease \nmonitoring.\nVerification of farmer-\nsubmitted reports.\nSeverity classification and \nescalation.\n\x00\nAgri News\nAccess to local and global \nagricultural developments.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 6, 'page_label': '7'}, page_content='/gC0F  Buyer Dashboard\nMarket trends\nAgri news\nMarketplace access'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 7, 'page_label': '8'}, page_content='/g1C  T echnology Stack\nFrontend\nReact (CRA)\nTailwind-style utility classes\nLucide-react icons\nRole-based routing\nBilingual UI\nBackend\nNode.js + Express\nJWT Authentication\nMongoDB (Users, \nDiseaseReports, Feedback, \nReputation)\nREST APIs\nAI Services\nFastAPI\nTensorFlow / Keras \n(MobileNetV2-based CNNs)\nJoblib models for crop \nsuitability\nYield prediction models\nData\nLabeled leaf image datasets \n(train/validation/test)\nDisease metadata JSON\nHistorical paddy statistics (10 \nyears)\nCrop suitability datasets\nDeployment\nDocker & Docker Compose\nEnvironment-based \nconfiguration'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 8, 'page_label': '9'}, page_content='/g1E  Innovation\nGrad-CAM Explainable AI for disease detection transparency\nMulti-crop AI detection within a unified inference pipeline\nCommunity disease intelligence with GN/DS/District-level granularity\nGovernment officer dashboards for area-wide monitoring and verification\nReputation-backed marketplace reducing middlemen dependency\nBilingual & voice-enabled UX for low digital-literacy users\nIn-chat image diagnosis with explainable outputs\nIntegrated news summaries with translation and audio support'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='/g20  Feasibility Analysis\nT echnical Feasibility\nUses widely adopted, open-\nsource technologies.\nAI models are already trained \nand functional.\nCloud-based architecture \nsupports scalability.\nOperational Feasibility\nFarmers require only a \nsmartphone.\nOfficers use standard web \ndashboards.\nMinimal training required for \nbasic usage.\nEconomic Feasibility\nLow development cost using \nopen-source tools.\nCan be deployed incrementally \n(district by district).\nSuitable for government or NGO \nadoption.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='/g22  Impact Assessment\nImpact on Farmers\nEarly and accurate disease \nidentification reduces crop loss\nImproved income through direct \nmarketplace access\nBetter decision-making through \nyield forecasts and advisories\nImproved accessibility through \nSinhala language and voice-\nbased interaction\nImpact on Buyers\nEasier access to verified \nfarmers\nTransparent pricing and market \ntrends\nReduced transaction friction \nthrough direct communication\nImpact on Government \nOfficers\nReal-time district-level disease \nmonitoring\nData-driven decision-making for \ninterventions and resource \nallocation\nImproved efficiency in \nagricultural management and \nplanning'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 11, 'page_label': '12'}, page_content='/g24  Additional Information\nDesigned as a scalable national platform\nThe Govi Isuru platform has been built with future expansion in mind, \ncapable of handling increased user loads and integrating new \nfeatures.\nSupports future integration with:\nSatellite data\nSMS-based alerts\nGovernment subsidy systems\nEthical AI usage with advisory-only predictions\nThe system is designed to provide guidance and insights, \nempowering users while ensuring human oversight in decision-\nmaking processes.')]

# %%
len(docs)
# Out:
# 12

# %%
docs[0]
# Out:
# Document(metadata={'producer': 'iLovePDF', 'creator': 'lightpdf.com', 'creationdate': '2025-12-28T19:44:54+00:00', 'author': 'lightpdf.com', 'subject': 'LightPDF - Edit, Convert PDF Files Online for Free', 'moddate': '2025-12-29T04:36:59+00:00', 'source': '/content/Project Proposal Devthon 3.0 Team Terrabytes DEV-0056.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='/g67A  Project Proposal ‒ Govi Isuru\nT eam Name\nTerraBytes\nT eam Leader\nH.M.Kalana Lakshan\nContact Email\nklacc2022@gmail.com\nContact Phone\n0703407328')

# %% [markdown]
# #Split documents into chunks

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

#initialize the text splitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 50)

#split the documents into chunks
splits = text_splitter.split_documents(docs)

# %%
len(splits)
# Out:
# 23
